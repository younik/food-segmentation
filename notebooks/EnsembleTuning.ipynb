# %%
# !pip install tensorflow_addons
from segnet import SegNet
from sequence import FoodSequence
from ensemble_net import EnsembleNet
import tensorflow as tf
import json
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Collecting tensorflow_addons
#   Downloading https://files.pythonhosted.org/packages/66/4b/e893d194e626c24b3df2253066aa418f46a432fdb68250cde14bf9bb0700/tensorflow_addons-0.13.0-cp37-cp37m-manylinux2010_x86_64.whl (679kB)
#      |████████████████████████████████| 686kB 3.9MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.13.0

# %%
def UNet(n_categories, 
         input_shape=(256, 256, 3),
         kernel=3,
         pool_size=(2,2), 
         output_mode='sigmoid'):


        inputs = Input(shape=input_shape)

        conv_1 = Convolution2D(64, (kernel, kernel), padding="same")(inputs)
        batch_1 = BatchNormalization()(conv_1)
        activation_1 = Activation("relu")(batch_1)
        conv_2 = Convolution2D(64, (kernel, kernel), padding="same")(activation_1)
        batch_2 = BatchNormalization()(conv_2)
        activation_2 = Activation("relu")(batch_2)

        pool_1 = MaxPooling2D(pool_size)(activation_2)

        conv_3 = Convolution2D(128, (kernel, kernel), padding="same")(pool_1)
        batch_3 = BatchNormalization()(conv_3)
        activation_3 = Activation("relu")(batch_3)
        conv_4 = Convolution2D(128, (kernel, kernel), padding="same")(activation_3)
        batch_4 = BatchNormalization()(conv_4)
        activation_4 = Activation("relu")(batch_4)

        pool_2 = MaxPooling2D(pool_size)(activation_4)

        conv_5 = Convolution2D(256, (kernel, kernel), padding="same")(pool_2)
        batch_5 = BatchNormalization()(conv_5)
        activation_5 = Activation("relu")(batch_5)
        conv_6 = Convolution2D(256, (kernel, kernel), padding="same")(activation_5)
        batch_6 = BatchNormalization()(conv_6)
        activation_6 = Activation("relu")(batch_6)

       
        pool_3 = MaxPooling2D(pool_size)(activation_6)

        conv_7 = Convolution2D(512, (kernel, kernel), padding="same")(pool_3)
        batch_7 = BatchNormalization()(conv_7)
        activation_7 = Activation("relu")(batch_7)
        conv_8 = Convolution2D(512, (kernel, kernel), padding="same")(activation_7)
        batch_8 = BatchNormalization()(conv_8)
        activation_8 = Activation("relu")(batch_8)

        pool_4 = MaxPooling2D(pool_size)(activation_8)

        conv_9 = Convolution2D(1024, (kernel, kernel), padding="same")(pool_4)
        batch_9 = BatchNormalization()(conv_9)
        activation_9 = Activation("relu")(batch_9)
        conv_10 = Convolution2D(1024, (kernel, kernel), padding="same")(activation_9)
        batch_10 = BatchNormalization()(conv_10)
        activation_10 = Activation("relu")(batch_10)

        # decoder

        unpool_1 = UpSampling2D(pool_size)(activation_10)

        conv_11 = Convolution2D(512, pool_size, padding="same")(unpool_1)
        batch_11 = BatchNormalization()(conv_11)
        #activation_11 = Activation("relu")(batch_11)
        merge_11 = Concatenate(axis=-1)([activation_8, batch_11])
        conv_12 = Convolution2D(512, (kernel, kernel), padding="same")(merge_11)
        batch_12 = BatchNormalization()(conv_12)
        activation_12 = Activation("relu")(batch_12)
        conv_13 = Convolution2D(512, (kernel, kernel), padding="same")(activation_12)
        batch_13 = BatchNormalization()(conv_13)
        activation_13 = Activation("relu")(batch_13)

        unpool_2 = UpSampling2D(pool_size)(activation_13)

        conv_14 = Convolution2D(256, pool_size, padding="same")(unpool_2)
        batch_14 = BatchNormalization()(conv_14)
        #activation_14 = Activation("relu")(batch_14)
        merge_14 = Concatenate(axis=-1)([activation_6, batch_14])
        conv_15 = Convolution2D(256, (kernel, kernel), padding="same")(merge_14)
        batch_15 = BatchNormalization()(conv_15)
        activation_15 = Activation("relu")(batch_15)
        conv_16 = Convolution2D(256, (kernel, kernel), padding="same")(activation_15)
        batch_16 = BatchNormalization()(conv_16)
        activation_16 = Activation("relu")(batch_16)

        unpool_3 = UpSampling2D(pool_size)(activation_16)

        conv_17 = Convolution2D(128, pool_size, padding="same")(unpool_3)
        batch_17 = BatchNormalization()(conv_17)
        #activation_17 = Activation("relu")(batch_17)
        merge_17 = Concatenate(axis=-1)([activation_4, batch_17])
        conv_18 = Convolution2D(128, (kernel, kernel), padding="same")(merge_17)
        batch_18 = BatchNormalization()(conv_18)
        activation_18 = Activation("relu")(batch_18)
        conv_19 = Convolution2D(128, (kernel, kernel), padding="same")(activation_18)
        batch_19 = BatchNormalization()(conv_19)
        activation_19 = Activation("relu")(batch_19)

        unpool_4 = UpSampling2D(pool_size)(activation_19)

        conv_20 = Convolution2D(64, pool_size, padding="same")(unpool_4)
        batch_20 = BatchNormalization()(conv_20)
        #activation_20 = Activation("relu")
        merge_20 = Concatenate(axis=-1)([activation_2, batch_20])
        conv_21 = Convolution2D(64, (kernel, kernel), padding="same")(merge_20)
        batch_21 = BatchNormalization()(conv_21)
        activation_21 = Activation("relu")(batch_21)
        conv_22 = Convolution2D(64, (kernel, kernel), padding="same")(activation_21)
        batch_22 = BatchNormalization()(conv_22)
        activation_22 = Activation("relu")(batch_22)

        conv_23 = Convolution2D(n_categories, (1, 1), padding="valid")(activation_22)
        outputs = Activation(output_mode)(conv_23)
        
        model = Model(inputs=inputs, outputs=outputs, name='U-Net')
        

        return model

# %%
# !pip install -U aicrowd-cli
API_KEY = "67587f4b3488144e75864045bf9db5e9" #get your api-key from https://www.aicrowd.com/participants/me

# !aicrowd login --api-key $API_KEY 
# !aicrowd dataset download --challenge food-recognition-challenge 3 4 5
# !tar -zxvf train-v0.4.tar.gz
# Out:
# Collecting aicrowd-cli
#   Downloading https://files.pythonhosted.org/packages/1f/57/59b5a00c6e90c9cc028b3da9dff90e242ad2847e735b1a0e81a21c616e27/aicrowd_cli-0.1.7-py3-none-any.whl (49kB)
#      |████████████████████████████████| 51kB 2.9MB/s
# Collecting requests-toolbelt<1,>=0.9.1
#   Downloading https://files.pythonhosted.org/packages/60/ef/7681134338fc097acef8d9b2f8abe0458e4d87559c689a8c306d0957ece5/requests_toolbelt-0.9.1-py2.py3-none-any.whl (54kB)
#      |████████████████████████████████| 61kB 6.4MB/s
# Collecting tqdm<5,>=4.56.0
#   Downloading https://files.pythonhosted.org/packages/b4/20/9f1e974bb4761128fc0d0a32813eaa92827309b1756c4b892d28adfb4415/tqdm-4.61.1-py2.py3-none-any.whl (75kB)
#      |████████████████████████████████| 81kB 5.1MB/s
# Collecting rich<11,>=10.0.0
#   Downloading https://files.pythonhosted.org/packages/69/a1/660d718e61d4c64fb8f1ef7b4aaf6db7a48a2b720cfac2991f06561d9a6c/rich-10.4.0-py3-none-any.whl (206kB)
#      |████████████████████████████████| 215kB 7.1MB/s
# Collecting requests<3,>=2.25.1
#   Downloading https://files.pythonhosted.org/packages/29/c1/24814557f1d22c56d50280771a17307e6bf87b70727d975fd6b2ce6b014a/requests-2.25.1-py2.py3-none-any.whl (61kB)
#      |████████████████████████████████| 61kB 5.2MB/s
# Requirement already satisfied, skipping upgrade: click<8,>=7.1.2 in /usr/local/lib/python3.7/dist-packages (from aicrowd-cli) (7.1.2)
# Collecting gitpython<4,>=3.1.12
#   Downloading https://files.pythonhosted.org/packages/bc/91/b38c4fabb6e5092ab23492ded4f318ab7299b19263272b703478038c0fbc/GitPython-3.1.18-py3-none-any.whl (170kB)
#      |████████████████████████████████| 174kB 7.4MB/s
# Requirement already satisfied, skipping upgrade: toml<1,>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from aicrowd-cli) (0.10.2)
# Requirement already satisfied, skipping upgrade: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich<11,>=10.0.0->aicrowd-cli) (2.6.1)
# Collecting colorama<0.5.0,>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading https://files.pythonhosted.org/packages/b1/92/dfd892312d822f36c55366118b95d914e5f16de11044a27cf10a7d71bbbf/commonmark-0.9.1-py2.py3-none-any.whl (51kB)
#      |████████████████████████████████| 51kB 4.8MB/s
# Requirement already satisfied, skipping upgrade: typing-extensions<4.0.0,>=3.7.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from rich<11,>=10.0.0->aicrowd-cli) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.25.1->aicrowd-cli) (2021.5.30)
# Requirement already satisfied, skipping upgrade: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.25.1->aicrowd-cli) (1.24.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.25.1->aicrowd-cli) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<5,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.25.1->aicrowd-cli) (3.0.4)
# Collecting gitdb<5,>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/ea/e8/f414d1a4f0bbc668ed441f74f44c116d9816833a48bf81d22b697090dba8/gitdb-4.0.7-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 5.6MB/s
# Collecting smmap<5,>=3.0.1
#   Downloading https://files.pythonhosted.org/packages/68/ee/d540eb5e5996eb81c26ceffac6ee49041d473bc5125f2aa995cf51ec1cf1/smmap-4.0.0-py2.py3-none-any.whl
# ERROR: google-colab 1.0.0 has requirement requests~=2.23.0, but you'll have requests 2.25.1 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# Installing collected packages: requests, requests-toolbelt, tqdm, colorama, commonmark, rich, smmap, gitdb, gitpython, aicrowd-cli
#   Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
# Successfully installed aicrowd-cli-0.1.7 colorama-0.4.4 commonmark-0.9.1 gitdb-4.0.7 gitpython-3.1.18 requests-2.25.1 requests-toolbelt-0.9.1 rich-10.4.0 smmap-4.0.0 tqdm-4.61.1
# Streaming output truncated to the last 5000 lines.
# ./train/images/016635.jpg
# ./train/images/084765.jpg
# ./train/images/030078.jpg
# ./train/images/095272.jpg
# ./train/images/074596.jpg
# ./train/images/068251.jpg
# ./train/images/021057.jpg
# ./train/images/098101.jpg
# ./train/images/094285.jpg
# ./train/images/007293.jpg
# ./train/images/099408.jpg
# ./train/images/019538.jpg
# ./train/images/049791.jpg
# ./train/images/021889.jpg
# ./train/images/075978.jpg
# ./train/images/043050.jpg
# ./train/images/077428.jpg
# ./train/images/026325.jpg
# ./train/images/008192.jpg
# ./train/images/082412.jpg
# ./train/images/013239.jpg
# ./train/images/028513.jpg
# ./train/images/084736.jpg
# ./train/images/076279.jpg
# ./train/images/103474.jpg
# ./train/images/070743.jpg
# ./train/images/071644.jpg
# ./train/images/095290.jpg
# ./train/images/037048.jpg
# ./train/images/009347.jpg
# ./train/images/078783.jpg
# ./train/images/084642.jpg
# ./train/images/032499.jpg
# ./train/images/099724.jpg
# ./train/images/079743.jpg
# ./train/images/074193.jpg
# ./train/images/021361.jpg
# ./train/images/059208.jpg
# ./train/images/022678.jpg
# ./train/images/011557.jpg
# ./train/images/071704.jpg
# ./train/images/021834.jpg
# ./train/images/047298.jpg
# ./train/images/069161.jpg
# ./train/images/061875.jpg
# ./train/images/045260.jpg
# ./train/images/060553.jpg
# ./train/images/025361.jpg
# ./train/images/033278.jpg
# ./train/images/014188.jpg
# ./train/images/035840.jpg
# ./train/images/079386.jpg
# ./train/images/095857.jpg
# ./train/images/073496.jpg
# ./train/images/071042.jpg
# ./train/images/083203.jpg
# ./train/images/058385.jpg
# ./train/images/083356.jpg
# ./train/images/052960.jpg
# ./train/images/078857.jpg
# ./train/images/047159.jpg
# ./train/images/032084.jpg
# ./train/images/030426.jpg
# ./train/images/037307.jpg
# ./train/images/020353.jpg
# ./train/images/008969.jpg
# ./train/images/050462.jpg
# ./train/images/092277.jpg
# ./train/images/026371.jpg
# ./train/images/072658.jpg
# ./train/images/012089.jpg
# ./train/images/049277.jpg
# ./train/images/046304.jpg
# ./train/images/058492.jpg
# ./train/images/029031.jpg
# ./train/images/095639.jpg
# ./train/images/071555.jpg
# ./train/images/087212.jpg
# ./train/images/050323.jpg
# ./train/images/008547.jpg
# ./train/images/009679.jpg
# ./train/images/009694.jpg
# ./train/images/017041.jpg
# ./train/images/027865.jpg
# ./train/images/098946.jpg
# ./train/images/086918.jpg
# ./train/images/084829.jpg
# ./train/images/093056.jpg
# ./train/images/073183.jpg
# ./train/images/090594.jpg
# ./train/images/023394.jpg
# ./train/images/021942.jpg
# ./train/images/035883.jpg
# ./train/images/048102.jpg
# ./train/images/021867.jpg
# ./train/images/021784.jpg
# ./train/images/052559.jpg
# ./train/images/029573.jpg
# ./train/images/018055.jpg
# ./train/images/069212.jpg
# ./train/images/095450.jpg
# ./train/images/069654.jpg
# ./train/images/053231.jpg
# ./train/images/045853.jpg
# ./train/images/011733.jpg
# ./train/images/089544.jpg
# ./train/images/073140.jpg
# ./train/images/017922.jpg
# ./train/images/061378.jpg
# ./train/images/102374.jpg
# ./train/images/051421.jpg
# ./train/images/038668.jpg
# ./train/images/056504.jpg
# ./train/images/034458.jpg
# ./train/images/032000.jpg
# ./train/images/077700.jpg
# ./train/images/047538.jpg
# ./train/images/049471.jpg
# ./train/images/088023.jpg
# ./train/images/075083.jpg
# ./train/images/096926.jpg
# ./train/images/014395.jpg
# ./train/images/069088.jpg
# ./train/images/045557.jpg
# ./train/images/079670.jpg
# ./train/images/007595.jpg
# ./train/images/053352.jpg
# ./train/images/092419.jpg
# ./train/images/056100.jpg
# ./train/images/060750.jpg
# ./train/images/028006.jpg
# ./train/images/016754.jpg
# ./train/images/036795.jpg
# ./train/images/094393.jpg
# ./train/images/096546.jpg
# ./train/images/039739.jpg
# ./train/images/038827.jpg
# ./train/images/092748.jpg
# ./train/images/086708.jpg
# ./train/images/055187.jpg
# ./train/images/095355.jpg
# ./train/images/026616.jpg
# ./train/images/068963.jpg
# ./train/images/048982.jpg
# ./train/images/064656.jpg
# ./train/images/088883.jpg
# ./train/images/007908.jpg
# ./train/images/084840.jpg
# ./train/images/072895.jpg
# ./train/images/059813.jpg
# ./train/images/041887.jpg
# ./train/images/021673.jpg
# ./train/images/073980.jpg
# ./train/images/035373.jpg
# ./train/images/051611.jpg
# ./train/images/086162.jpg
# ./train/images/072192.jpg
# ./train/images/067725.jpg
# ./train/images/041998.jpg
# ./train/images/032373.jpg
# ./train/images/058270.jpg
# ./train/images/023778.jpg
# ./train/images/081604.jpg
# ./train/images/026684.jpg
# ./train/images/092141.jpg
# ./train/images/037993.jpg
# ./train/images/064919.jpg
# ./train/images/096921.jpg
# ./train/images/016796.jpg
# ./train/images/006725.jpg
# ./train/images/103503.jpg
# ./train/images/102612.jpg
# ./train/images/020109.jpg
# ./train/images/019190.jpg
# ./train/images/079541.jpg
# ./train/images/077041.jpg
# ./train/images/055936.jpg
# ./train/images/071719.jpg
# ./train/images/041862.jpg
# ./train/images/100298.jpg
# ./train/images/097169.jpg
# ./train/images/030846.jpg
# ./train/images/088733.jpg
# ./train/images/033283.jpg
# ./train/images/074023.jpg
# ./train/images/052245.jpg
# ./train/images/039295.jpg
# ./train/images/023623.jpg
# ./train/images/061087.jpg
# ./train/images/084628.jpg
# ./train/images/028600.jpg
# ./train/images/018838.jpg
# ./train/images/103882.jpg
# ./train/images/026934.jpg
# ./train/images/016267.jpg
# ./train/images/028017.jpg
# ./train/images/067590.jpg
# ./train/images/023556.jpg
# ./train/images/008201.jpg
# ./train/images/015497.jpg
# ./train/images/009437.jpg
# ./train/images/081382.jpg
# ./train/images/046688.jpg
# ./train/images/008188.jpg
# ./train/images/103167.jpg
# ./train/images/102112.jpg
# ./train/images/009572.jpg
# ./train/images/089356.jpg
# ./train/images/065820.jpg
# ./train/images/079295.jpg
# ./train/images/101748.jpg
# ./train/images/095145.jpg
# ./train/images/089696.jpg
# ./train/images/037502.jpg
# ./train/images/032433.jpg
# ./train/images/043062.jpg
# ./train/images/093730.jpg
# ./train/images/064002.jpg
# ./train/images/008519.jpg
# ./train/images/008700.jpg
# ./train/images/097187.jpg
# ./train/images/102730.jpg
# ./train/images/048967.jpg
# ./train/images/027952.jpg
# ./train/images/018136.jpg
# ./train/images/100433.jpg
# ./train/images/040431.jpg
# ./train/images/084384.jpg
# ./train/images/022370.jpg
# ./train/images/038981.jpg
# ./train/images/083415.jpg
# ./train/images/012007.jpg
# ./train/images/070390.jpg
# ./train/images/086763.jpg
# ./train/images/028903.jpg
# ./train/images/017793.jpg
# ./train/images/073550.jpg
# ./train/images/103335.jpg
# ./train/images/059827.jpg
# ./train/images/094084.jpg
# ./train/images/091301.jpg
# ./train/images/013487.jpg
# ./train/images/089745.jpg
# ./train/images/098168.jpg
# ./train/images/012771.jpg
# ./train/images/055977.jpg
# ./train/images/017017.jpg
# ./train/images/052616.jpg
# ./train/images/036005.jpg
# ./train/images/099999.jpg
# ./train/images/012364.jpg
# ./train/images/050605.jpg
# ./train/images/083188.jpg
# ./train/images/032094.jpg
# ./train/images/021117.jpg
# ./train/images/054685.jpg
# ./train/images/040030.jpg
# ./train/images/076486.jpg
# ./train/images/035956.jpg
# ./train/images/095180.jpg
# ./train/images/080025.jpg
# ./train/images/083057.jpg
# ./train/images/087687.jpg
# ./train/images/087139.jpg
# ./train/images/044114.jpg
# ./train/images/096548.jpg
# ./train/images/073831.jpg
# ./train/images/055156.jpg
# ./train/images/058271.jpg
# ./train/images/076303.jpg
# ./train/images/087163.jpg
# ./train/images/024105.jpg
# ./train/images/100175.jpg
# ./train/images/070873.jpg
# ./train/images/075037.jpg
# ./train/images/075198.jpg
# ./train/images/078791.jpg
# ./train/images/051292.jpg
# ./train/images/102842.jpg
# ./train/images/095426.jpg
# ./train/images/089611.jpg
# ./train/images/078437.jpg
# ./train/images/066004.jpg
# ./train/images/077695.jpg
# ./train/images/091414.jpg
# ./train/images/076175.jpg
# ./train/images/036935.jpg
# ./train/images/038009.jpg
# ./train/images/095995.jpg
# ./train/images/095997.jpg
# ./train/images/071465.jpg
# ./train/images/089254.jpg
# ./train/images/014982.jpg
# ./train/images/016249.jpg
# ./train/images/023204.jpg
# ./train/images/039964.jpg
# ./train/images/068450.jpg
# ./train/images/016624.jpg
# ./train/images/102689.jpg
# ./train/images/076814.jpg
# ./train/images/042189.jpg
# ./train/images/039020.jpg
# ./train/images/034418.jpg
# ./train/images/017501.jpg
# ./train/images/064056.jpg
# ./train/images/076926.jpg
# ./train/images/070011.jpg
# ./train/images/053970.jpg
# ./train/images/035712.jpg
# ./train/images/091497.jpg
# ./train/images/082355.jpg
# ./train/images/035420.jpg
# ./train/images/011611.jpg
# ./train/images/068462.jpg
# ./train/images/023568.jpg
# ./train/images/098275.jpg
# ./train/images/009370.jpg
# ./train/images/055378.jpg
# ./train/images/048515.jpg
# ./train/images/020672.jpg
# ./train/images/084687.jpg
# ./train/images/050869.jpg
# ./train/images/080842.jpg
# ./train/images/069799.jpg
# ./train/images/025671.jpg
# ./train/images/054178.jpg
# ./train/images/038865.jpg
# ./train/images/033367.jpg
# ./train/images/028733.jpg
# ./train/images/100991.jpg
# ./train/images/012824.jpg
# ./train/images/031367.jpg
# ./train/images/038431.jpg
# ./train/images/035215.jpg
# ./train/images/086326.jpg
# ./train/images/008975.jpg
# ./train/images/016544.jpg
# ./train/images/039763.jpg
# ./train/images/097341.jpg
# ./train/images/089753.jpg
# ./train/images/034334.jpg
# ./train/images/038808.jpg
# ./train/images/026444.jpg
# ./train/images/099240.jpg
# ./train/images/019742.jpg
# ./train/images/073921.jpg
# ./train/images/104255.jpg
# ./train/images/037214.jpg
# ./train/images/045622.jpg
# ./train/images/085398.jpg
# ./train/images/042853.jpg
# ./train/images/039219.jpg
# ./train/images/093848.jpg
# ./train/images/076831.jpg
# ./train/images/087714.jpg
# ./train/images/065223.jpg
# ./train/images/049204.jpg
# ./train/images/102395.jpg
# ./train/images/046083.jpg
# ./train/images/053064.jpg
# ./train/images/046849.jpg
# ./train/images/011832.jpg
# ./train/images/091685.jpg
# ./train/images/098535.jpg
# ./train/images/037324.jpg
# ./train/images/053917.jpg
# ./train/images/037295.jpg
# ./train/images/031976.jpg
# ./train/images/072424.jpg
# ./train/images/033067.jpg
# ./train/images/096463.jpg
# ./train/images/078938.jpg
# ./train/images/037486.jpg
# ./train/images/071052.jpg
# ./train/images/058742.jpg
# ./train/images/054032.jpg
# ./train/images/094595.jpg
# ./train/images/060175.jpg
# ./train/images/071666.jpg
# ./train/images/052876.jpg
# ./train/images/023619.jpg
# ./train/images/082735.jpg
# ./train/images/097665.jpg
# ./train/images/067998.jpg
# ./train/images/019956.jpg
# ./train/images/087697.jpg
# ./train/images/086586.jpg
# ./train/images/096784.jpg
# ./train/images/035688.jpg
# ./train/images/085072.jpg
# ./train/images/091103.jpg
# ./train/images/057499.jpg
# ./train/images/062997.jpg
# ./train/images/038867.jpg
# ./train/images/045315.jpg
# ./train/images/037203.jpg
# ./train/images/031690.jpg
# ./train/images/011568.jpg
# ./train/images/089700.jpg
# ./train/images/008717.jpg
# ./train/images/087162.jpg
# ./train/images/020417.jpg
# ./train/images/038547.jpg
# ./train/images/082203.jpg
# ./train/images/033007.jpg
# ./train/images/066320.jpg
# ./train/images/079721.jpg
# ./train/images/022715.jpg
# ./train/images/023016.jpg
# ./train/images/075714.jpg
# ./train/images/073473.jpg
# ./train/images/041000.jpg
# ./train/images/048918.jpg
# ./train/images/034274.jpg
# ./train/images/035750.jpg
# ./train/images/094527.jpg
# ./train/images/081997.jpg
# ./train/images/092182.jpg
# ./train/images/052868.jpg
# ./train/images/019296.jpg
# ./train/images/089970.jpg
# ./train/images/040711.jpg
# ./train/images/086095.jpg
# ./train/images/016922.jpg
# ./train/images/041064.jpg
# ./train/images/084025.jpg
# ./train/images/050291.jpg
# ./train/images/021915.jpg
# ./train/images/042415.jpg
# ./train/images/098951.jpg
# ./train/images/018339.jpg
# ./train/images/063185.jpg
# ./train/images/094302.jpg
# ./train/images/103209.jpg
# ./train/images/020888.jpg
# ./train/images/052486.jpg
# ./train/images/087519.jpg
# ./train/images/047481.jpg
# ./train/images/072384.jpg
# ./train/images/082542.jpg
# ./train/images/102802.jpg
# ./train/images/076958.jpg
# ./train/images/080009.jpg
# ./train/images/086718.jpg
# ./train/images/011904.jpg
# ./train/images/072227.jpg
# ./train/images/076034.jpg
# ./train/images/045600.jpg
# ./train/images/072251.jpg
# ./train/images/072304.jpg
# ./train/images/086789.jpg
# ./train/images/025261.jpg
# ./train/images/056914.jpg
# ./train/images/100213.jpg
# ./train/images/080446.jpg
# ./train/images/077343.jpg
# ./train/images/058159.jpg
# ./train/images/057268.jpg
# ./train/images/047982.jpg
# ./train/images/094753.jpg
# ./train/images/100150.jpg
# ./train/images/079636.jpg
# ./train/images/032538.jpg
# ./train/images/032766.jpg
# ./train/images/026644.jpg
# ./train/images/102704.jpg
# ./train/images/072134.jpg
# ./train/images/067611.jpg
# ./train/images/104498.jpg
# ./train/images/040313.jpg
# ./train/images/043263.jpg
# ./train/images/100022.jpg
# ./train/images/054341.jpg
# ./train/images/036112.jpg
# ./train/images/092871.jpg
# ./train/images/052698.jpg
# ./train/images/035522.jpg
# ./train/images/069087.jpg
# ./train/images/011561.jpg
# ./train/images/051200.jpg
# ./train/images/027172.jpg
# ./train/images/078155.jpg
# ./train/images/076517.jpg
# ./train/images/035560.jpg
# ./train/images/012575.jpg
# ./train/images/013899.jpg
# ./train/images/063032.jpg
# ./train/images/033545.jpg
# ./train/images/081921.jpg
# ./train/images/068861.jpg
# ./train/images/065658.jpg
# ./train/images/094970.jpg
# ./train/images/069905.jpg
# ./train/images/075999.jpg
# ./train/images/019228.jpg
# ./train/images/034434.jpg
# ./train/images/096305.jpg
# ./train/images/078815.jpg
# ./train/images/083416.jpg
# ./train/images/088174.jpg
# ./train/images/060741.jpg
# ./train/images/036141.jpg
# ./train/images/102454.jpg
# ./train/images/075249.jpg
# ./train/images/031829.jpg
# ./train/images/029019.jpg
# ./train/images/058105.jpg
# ./train/images/041706.jpg
# ./train/images/095232.jpg
# ./train/images/033804.jpg
# ./train/images/059967.jpg
# ./train/images/027934.jpg
# ./train/images/080303.jpg
# ./train/images/065348.jpg
# ./train/images/077935.jpg
# ./train/images/075717.jpg
# ./train/images/017368.jpg
# ./train/images/021904.jpg
# ./train/images/021292.jpg
# ./train/images/103518.jpg
# ./train/images/070730.jpg
# ./train/images/069806.jpg
# ./train/images/097037.jpg
# ./train/images/006775.jpg
# ./train/images/023782.jpg
# ./train/images/007674.jpg
# ./train/images/024160.jpg
# ./train/images/079463.jpg
# ./train/images/044977.jpg
# ./train/images/053041.jpg
# ./train/images/054368.jpg
# ./train/images/009259.jpg
# ./train/images/008079.jpg
# ./train/images/041392.jpg
# ./train/images/015180.jpg
# ./train/images/095718.jpg
# ./train/images/021065.jpg
# ./train/images/070628.jpg
# ./train/images/076775.jpg
# ./train/images/070437.jpg
# ./train/images/029444.jpg
# ./train/images/048429.jpg
# ./train/images/067586.jpg
# ./train/images/087579.jpg
# ./train/images/032068.jpg
# ./train/images/085461.jpg
# ./train/images/068255.jpg
# ./train/images/069133.jpg
# ./train/images/042120.jpg
# ./train/images/103638.jpg
# ./train/images/054737.jpg
# ./train/images/102989.jpg
# ./train/images/073836.jpg
# ./train/images/040888.jpg
# ./train/images/102677.jpg
# ./train/images/093149.jpg
# ./train/images/095653.jpg
# ./train/images/072409.jpg
# ./train/images/088921.jpg
# ./train/images/083342.jpg
# ./train/images/056596.jpg
# ./train/images/074268.jpg
# ./train/images/018002.jpg
# ./train/images/069234.jpg
# ./train/images/069367.jpg
# ./train/images/101260.jpg
# ./train/images/039657.jpg
# ./train/images/091323.jpg
# ./train/images/029704.jpg
# ./train/images/009476.jpg
# ./train/images/084123.jpg
# ./train/images/031096.jpg
# ./train/images/030079.jpg
# ./train/images/083646.jpg
# ./train/images/076654.jpg
# ./train/images/088090.jpg
# ./train/images/085534.jpg
# ./train/images/068668.jpg
# ./train/images/075930.jpg
# ./train/images/080201.jpg
# ./train/images/026073.jpg
# ./train/images/103798.jpg
# ./train/images/044602.jpg
# ./train/images/042615.jpg
# ./train/images/102281.jpg
# ./train/images/050748.jpg
# ./train/images/090308.jpg
# ./train/images/102387.jpg
# ./train/images/032266.jpg
# ./train/images/009196.jpg
# ./train/images/101747.jpg
# ./train/images/033073.jpg
# ./train/images/039935.jpg
# ./train/images/036220.jpg
# ./train/images/022566.jpg
# ./train/images/045001.jpg
# ./train/images/052417.jpg
# ./train/images/062151.jpg
# ./train/images/093484.jpg
# ./train/images/064318.jpg
# ./train/images/019857.jpg
# ./train/images/098406.jpg
# ./train/images/008226.jpg
# ./train/images/064490.jpg
# ./train/images/079203.jpg
# ./train/images/102028.jpg
# ./train/images/060487.jpg
# ./train/images/028994.jpg
# ./train/images/082556.jpg
# ./train/images/009688.jpg
# ./train/images/096707.jpg
# ./train/images/010450.jpg
# ./train/images/052656.jpg
# ./train/images/062946.jpg
# ./train/images/048984.jpg
# ./train/images/025165.jpg
# ./train/images/053705.jpg
# ./train/images/076869.jpg
# ./train/images/100860.jpg
# ./train/images/096526.jpg
# ./train/images/024296.jpg
# ./train/images/092047.jpg
# ./train/images/021237.jpg
# ./train/images/053043.jpg
# ./train/images/037788.jpg
# ./train/images/038561.jpg
# ./train/images/035604.jpg
# ./train/images/095556.jpg
# ./train/images/021711.jpg
# ./train/images/095074.jpg
# ./train/images/046351.jpg
# ./train/images/020733.jpg
# ./train/images/093058.jpg
# ./train/images/038560.jpg
# ./train/images/098291.jpg
# ./train/images/071717.jpg
# ./train/images/028288.jpg
# ./train/images/089476.jpg
# ./train/images/036707.jpg
# ./train/images/050095.jpg
# ./train/images/079331.jpg
# ./train/images/070788.jpg
# ./train/images/013760.jpg
# ./train/images/042239.jpg
# ./train/images/046365.jpg
# ./train/images/076371.jpg
# ./train/images/076347.jpg
# ./train/images/054590.jpg
# ./train/images/054199.jpg
# ./train/images/013570.jpg
# ./train/images/011280.jpg
# ./train/images/071623.jpg
# ./train/images/014323.jpg
# ./train/images/095814.jpg
# ./train/images/031039.jpg
# ./train/images/074917.jpg
# ./train/images/012597.jpg
# ./train/images/085561.jpg
# ./train/images/010357.jpg
# ./train/images/075887.jpg
# ./train/images/059155.jpg
# ./train/images/006470.jpg
# ./train/images/045648.jpg
# ./train/images/076180.jpg
# ./train/images/037019.jpg
# ./train/images/006979.jpg
# ./train/images/009307.jpg
# ./train/images/038480.jpg
# ./train/images/070141.jpg
# ./train/images/036718.jpg
# ./train/images/018635.jpg
# ./train/images/082110.jpg
# ./train/images/080882.jpg
# ./train/images/049263.jpg
# ./train/images/070386.jpg
# ./train/images/051566.jpg
# ./train/images/091422.jpg
# ./train/images/096206.jpg
# ./train/images/035307.jpg
# ./train/images/019826.jpg
# ./train/images/026689.jpg
# ./train/images/022944.jpg
# ./train/images/093585.jpg
# ./train/images/024641.jpg
# ./train/images/015308.jpg
# ./train/images/086764.jpg
# ./train/images/067904.jpg
# ./train/images/093271.jpg
# ./train/images/085460.jpg
# ./train/images/100133.jpg
# ./train/images/074229.jpg
# ./train/images/046292.jpg
# ./train/images/100954.jpg
# ./train/images/090476.jpg
# ./train/images/053284.jpg
# ./train/images/075156.jpg
# ./train/images/062667.jpg
# ./train/images/018967.jpg
# ./train/images/014751.jpg
# ./train/images/095515.jpg
# ./train/images/030633.jpg
# ./train/images/101226.jpg
# ./train/images/050665.jpg
# ./train/images/013635.jpg
# ./train/images/077435.jpg
# ./train/images/102457.jpg
# ./train/images/008021.jpg
# ./train/images/033253.jpg
# ./train/images/086906.jpg
# ./train/images/037760.jpg
# ./train/images/039572.jpg
# ./train/images/008939.jpg
# ./train/images/032134.jpg
# ./train/images/084979.jpg
# ./train/images/060610.jpg
# ./train/images/048528.jpg
# ./train/images/090474.jpg
# ./train/images/023940.jpg
# ./train/images/015117.jpg
# ./train/images/101107.jpg
# ./train/images/034574.jpg
# ./train/images/016269.jpg
# ./train/images/044251.jpg
# ./train/images/053966.jpg
# ./train/images/052717.jpg
# ./train/images/063142.jpg
# ./train/images/087655.jpg
# ./train/images/018906.jpg
# ./train/images/046754.jpg
# ./train/images/066318.jpg
# ./train/images/099251.jpg
# ./train/images/050449.jpg
# ./train/images/020681.jpg
# ./train/images/056053.jpg
# ./train/images/028452.jpg
# ./train/images/083385.jpg
# ./train/images/044223.jpg
# ./train/images/092762.jpg
# ./train/images/015941.jpg
# ./train/images/091181.jpg
# ./train/images/101135.jpg
# ./train/images/048498.jpg
# ./train/images/038576.jpg
# ./train/images/036116.jpg
# ./train/images/074628.jpg
# ./train/images/006572.jpg
# ./train/images/090814.jpg
# ./train/images/009908.jpg
# ./train/images/084517.jpg
# ./train/images/082843.jpg
# ./train/images/064654.jpg
# ./train/images/072341.jpg
# ./train/images/047703.jpg
# ./train/images/011482.jpg
# ./train/images/025013.jpg
# ./train/images/036867.jpg
# ./train/images/052818.jpg
# ./train/images/080694.jpg
# ./train/images/029015.jpg
# ./train/images/077672.jpg
# ./train/images/100436.jpg
# ./train/images/092157.jpg
# ./train/images/075090.jpg
# ./train/images/044714.jpg
# ./train/images/075985.jpg
# ./train/images/071727.jpg
# ./train/images/033501.jpg
# ./train/images/079603.jpg
# ./train/images/021264.jpg
# ./train/images/089942.jpg
# ./train/images/077607.jpg
# ./train/images/010580.jpg
# ./train/images/083442.jpg
# ./train/images/095607.jpg
# ./train/images/010909.jpg
# ./train/images/010872.jpg
# ./train/images/101335.jpg
# ./train/images/078221.jpg
# ./train/images/020057.jpg
# ./train/images/035059.jpg
# ./train/images/085700.jpg
# ./train/images/007658.jpg
# ./train/images/100702.jpg
# ./train/images/093771.jpg
# ./train/images/102255.jpg
# ./train/images/038707.jpg
# ./train/images/022201.jpg
# ./train/images/021782.jpg
# ./train/images/025179.jpg
# ./train/images/075886.jpg
# ./train/images/070586.jpg
# ./train/images/074808.jpg
# ./train/images/041681.jpg
# ./train/images/058072.jpg
# ./train/images/068300.jpg
# ./train/images/090789.jpg
# ./train/images/048709.jpg
# ./train/images/070236.jpg
# ./train/images/064396.jpg
# ./train/images/069848.jpg
# ./train/images/079115.jpg
# ./train/images/085945.jpg
# ./train/images/030974.jpg
# ./train/images/083771.jpg
# ./train/images/009613.jpg
# ./train/images/038313.jpg
# ./train/images/065008.jpg
# ./train/images/074885.jpg
# ./train/images/084373.jpg
# ./train/images/059167.jpg
# ./train/images/009253.jpg
# ./train/images/046735.jpg
# ./train/images/082618.jpg
# ./train/images/079106.jpg
# ./train/images/070860.jpg
# ./train/images/087715.jpg
# ./train/images/084726.jpg
# ./train/images/055343.jpg
# ./train/images/051815.jpg
# ./train/images/061597.jpg
# ./train/images/071191.jpg
# ./train/images/049118.jpg
# ./train/images/016623.jpg
# ./train/images/026220.jpg
# ./train/images/084904.jpg
# ./train/images/070762.jpg
# ./train/images/007881.jpg
# ./train/images/084136.jpg
# ./train/images/077027.jpg
# ./train/images/009968.jpg
# ./train/images/054328.jpg
# ./train/images/018408.jpg
# ./train/images/010644.jpg
# ./train/images/089241.jpg
# ./train/images/041242.jpg
# ./train/images/087892.jpg
# ./train/images/094210.jpg
# ./train/images/046302.jpg
# ./train/images/077142.jpg
# ./train/images/034221.jpg
# ./train/images/085202.jpg
# ./train/images/044609.jpg
# ./train/images/036523.jpg
# ./train/images/082183.jpg
# ./train/images/099047.jpg
# ./train/images/086686.jpg
# ./train/images/015946.jpg
# ./train/images/079704.jpg
# ./train/images/031589.jpg
# ./train/images/008790.jpg
# ./train/images/069637.jpg
# ./train/images/038573.jpg
# ./train/images/069143.jpg
# ./train/images/100866.jpg
# ./train/images/006685.jpg
# ./train/images/085193.jpg
# ./train/images/008207.jpg
# ./train/images/071633.jpg
# ./train/images/102256.jpg
# ./train/images/095852.jpg
# ./train/images/032492.jpg
# ./train/images/091667.jpg
# ./train/images/017451.jpg
# ./train/images/040412.jpg
# ./train/images/037979.jpg
# ./train/images/081222.jpg
# ./train/images/030824.jpg
# ./train/images/043102.jpg
# ./train/images/037825.jpg
# ./train/images/099505.jpg
# ./train/images/068634.jpg
# ./train/images/073392.jpg
# ./train/images/017670.jpg
# ./train/images/031925.jpg
# ./train/images/041399.jpg
# ./train/images/019856.jpg
# ./train/images/090845.jpg
# ./train/images/031790.jpg
# ./train/images/028737.jpg
# ./train/images/076277.jpg
# ./train/images/071402.jpg
# ./train/images/101454.jpg
# ./train/images/085463.jpg
# ./train/images/083511.jpg
# ./train/images/084205.jpg
# ./train/images/007769.jpg
# ./train/images/075847.jpg
# ./train/images/092256.jpg
# ./train/images/083331.jpg
# ./train/images/022759.jpg
# ./train/images/014742.jpg
# ./train/images/100842.jpg
# ./train/images/029673.jpg
# ./train/images/095917.jpg
# ./train/images/007748.jpg
# ./train/images/046123.jpg
# ./train/images/068377.jpg
# ./train/images/085930.jpg
# ./train/images/071551.jpg
# ./train/images/034985.jpg
# ./train/images/014433.jpg
# ./train/images/090521.jpg
# ./train/images/043948.jpg
# ./train/images/094313.jpg
# ./train/images/070524.jpg
# ./train/images/025521.jpg
# ./train/images/033838.jpg
# ./train/images/075905.jpg
# ./train/images/080309.jpg
# ./train/images/011382.jpg
# ./train/images/024412.jpg
# ./train/images/073913.jpg
# ./train/images/016864.jpg
# ./train/images/034060.jpg
# ./train/images/041918.jpg
# ./train/images/007911.jpg
# ./train/images/028624.jpg
# ./train/images/044730.jpg
# ./train/images/081498.jpg
# ./train/images/070414.jpg
# ./train/images/011710.jpg
# ./train/images/015296.jpg
# ./train/images/075882.jpg
# ./train/images/096916.jpg
# ./train/images/024556.jpg
# ./train/images/052321.jpg
# ./train/images/096762.jpg
# ./train/images/084474.jpg
# ./train/images/032767.jpg
# ./train/images/077637.jpg
# ./train/images/069968.jpg
# ./train/images/066562.jpg
# ./train/images/087068.jpg
# ./train/images/059565.jpg
# ./train/images/093980.jpg
# ./train/images/102971.jpg
# ./train/images/036939.jpg
# ./train/images/075292.jpg
# ./train/images/016190.jpg
# ./train/images/041692.jpg
# ./train/images/054413.jpg
# ./train/images/031607.jpg
# ./train/images/077739.jpg
# ./train/images/032109.jpg
# ./train/images/026609.jpg
# ./train/images/034752.jpg
# ./train/images/010735.jpg
# ./train/images/009326.jpg
# ./train/images/085900.jpg
# ./train/images/072911.jpg
# ./train/images/020303.jpg
# ./train/images/024764.jpg
# ./train/images/056840.jpg
# ./train/images/058810.jpg
# ./train/images/030241.jpg
# ./train/images/083237.jpg
# ./train/images/077491.jpg
# ./train/images/011929.jpg
# ./train/images/084477.jpg
# ./train/images/097416.jpg
# ./train/images/086928.jpg
# ./train/images/103442.jpg
# ./train/images/028010.jpg
# ./train/images/068257.jpg
# ./train/images/087508.jpg
# ./train/images/037636.jpg
# ./train/images/025565.jpg
# ./train/images/041584.jpg
# ./train/images/047034.jpg
# ./train/images/053342.jpg
# ./train/images/072131.jpg
# ./train/images/040425.jpg
# ./train/images/050446.jpg
# ./train/images/090577.jpg
# ./train/images/097725.jpg
# ./train/images/017126.jpg
# ./train/images/097798.jpg
# ./train/images/039991.jpg
# ./train/images/067164.jpg
# ./train/images/071166.jpg
# ./train/images/047595.jpg
# ./train/images/092230.jpg
# ./train/images/028630.jpg
# ./train/images/076679.jpg
# ./train/images/069192.jpg
# ./train/images/096469.jpg
# ./train/images/102731.jpg
# ./train/images/100234.jpg
# ./train/images/088264.jpg
# ./train/images/010785.jpg
# ./train/images/083983.jpg
# ./train/images/077592.jpg
# ./train/images/032879.jpg
# ./train/images/011115.jpg
# ./train/images/033380.jpg
# ./train/images/089618.jpg
# ./train/images/086724.jpg
# ./train/images/027544.jpg
# ./train/images/057726.jpg
# ./train/images/083082.jpg
# ./train/images/072113.jpg
# ./train/images/032562.jpg
# ./train/images/102578.jpg
# ./train/images/011276.jpg
# ./train/images/095553.jpg
# ./train/images/040777.jpg
# ./train/images/074918.jpg
# ./train/images/010294.jpg
# ./train/images/034779.jpg
# ./train/images/018853.jpg
# ./train/images/014475.jpg
# ./train/images/041072.jpg
# ./train/images/068701.jpg
# ./train/images/051235.jpg
# ./train/images/067757.jpg
# ./train/images/068010.jpg
# ./train/images/097754.jpg
# ./train/images/064426.jpg
# ./train/images/053988.jpg
# ./train/images/050545.jpg
# ./train/images/055066.jpg
# ./train/images/053868.jpg
# ./train/images/026608.jpg
# ./train/images/015336.jpg
# ./train/images/079253.jpg
# ./train/images/059126.jpg
# ./train/images/096173.jpg
# ./train/images/096465.jpg
# ./train/images/090995.jpg
# ./train/images/023461.jpg
# ./train/images/046474.jpg
# ./train/images/092707.jpg
# ./train/images/023585.jpg
# ./train/images/070595.jpg
# ./train/images/016545.jpg
# ./train/images/094328.jpg
# ./train/images/006940.jpg
# ./train/images/100849.jpg
# ./train/images/034290.jpg
# ./train/images/095424.jpg
# ./train/images/075354.jpg
# ./train/images/089013.jpg
# ./train/images/087643.jpg
# ./train/images/059273.jpg
# ./train/images/041632.jpg
# ./train/images/068772.jpg
# ./train/images/080883.jpg
# ./train/images/085904.jpg
# ./train/images/087170.jpg
# ./train/images/072389.jpg
# ./train/images/071897.jpg
# ./train/images/049469.jpg
# ./train/images/076403.jpg
# ./train/images/076655.jpg
# ./train/images/046412.jpg
# ./train/images/013722.jpg
# ./train/images/014830.jpg
# ./train/images/071634.jpg
# ./train/images/047120.jpg
# ./train/images/088461.jpg
# ./train/images/055901.jpg
# ./train/images/095428.jpg
# ./train/images/015803.jpg
# ./train/images/082837.jpg
# ./train/images/092204.jpg
# ./train/images/037941.jpg
# ./train/images/032282.jpg
# ./train/images/039582.jpg
# ./train/images/054850.jpg
# ./train/images/090177.jpg
# ./train/images/103351.jpg
# ./train/images/013890.jpg
# ./train/images/070095.jpg
# ./train/images/029143.jpg
# ./train/images/050868.jpg
# ./train/images/008596.jpg
# ./train/images/038271.jpg
# ./train/images/082010.jpg
# ./train/images/073066.jpg
# ./train/images/087207.jpg
# ./train/images/055025.jpg
# ./train/images/088715.jpg
# ./train/images/035248.jpg
# ./train/images/094246.jpg
# ./train/images/032662.jpg
# ./train/images/089196.jpg
# ./train/images/031936.jpg
# ./train/images/030883.jpg
# ./train/images/038519.jpg
# ./train/images/033402.jpg
# ./train/images/073797.jpg
# ./train/images/036156.jpg
# ./train/images/037085.jpg
# ./train/images/084405.jpg
# ./train/images/018417.jpg
# ./train/images/097986.jpg
# ./train/images/033730.jpg
# ./train/images/030176.jpg
# ./train/images/026656.jpg
# ./train/images/102149.jpg
# ./train/images/101935.jpg
# ./train/images/041077.jpg
# ./train/images/072315.jpg
# ./train/images/097779.jpg
# ./train/images/030212.jpg
# ./train/images/008647.jpg
# ./train/images/072547.jpg
# ./train/images/071821.jpg
# ./train/images/088446.jpg
# ./train/images/088099.jpg
# ./train/images/072081.jpg
# ./train/images/102803.jpg
# ./train/images/081592.jpg
# ./train/images/101623.jpg
# ./train/images/073787.jpg
# ./train/images/104159.jpg
# ./train/images/089648.jpg
# ./train/images/047631.jpg
# ./train/images/025920.jpg
# ./train/images/020910.jpg
# ./train/images/097571.jpg
# ./train/images/044313.jpg
# ./train/images/095167.jpg
# ./train/images/020406.jpg
# ./train/images/074237.jpg
# ./train/images/071586.jpg
# ./train/images/026806.jpg
# ./train/images/088789.jpg
# ./train/images/045479.jpg
# ./train/images/043110.jpg
# ./train/images/078567.jpg
# ./train/images/025647.jpg
# ./train/images/098966.jpg
# ./train/images/034876.jpg
# ./train/images/088969.jpg
# ./train/images/030091.jpg
# ./train/images/015807.jpg
# ./train/images/032321.jpg
# ./train/images/055148.jpg
# ./train/images/074755.jpg
# ./train/images/015503.jpg
# ./train/images/069102.jpg
# ./train/images/099031.jpg
# ./train/images/080686.jpg
# ./train/images/087359.jpg
# ./train/images/025488.jpg
# ./train/images/101943.jpg
# ./train/images/095910.jpg
# ./train/images/070932.jpg
# ./train/images/090522.jpg
# ./train/images/053396.jpg
# ./train/images/076703.jpg
# ./train/images/104212.jpg
# ./train/images/088347.jpg
# ./train/images/038466.jpg
# ./train/images/054086.jpg
# ./train/images/103352.jpg
# ./train/images/034405.jpg
# ./train/images/022286.jpg
# ./train/images/080298.jpg
# ./train/images/028063.jpg
# ./train/images/038413.jpg
# ./train/images/072982.jpg
# ./train/images/101221.jpg
# ./train/images/016722.jpg
# ./train/images/084716.jpg
# ./train/images/014441.jpg
# ./train/images/013547.jpg
# ./train/images/093620.jpg
# ./train/images/091421.jpg
# ./train/images/024980.jpg
# ./train/images/073763.jpg
# ./train/images/040533.jpg
# ./train/images/045371.jpg
# ./train/images/023393.jpg
# ./train/images/059461.jpg
# ./train/images/047589.jpg
# ./train/images/015254.jpg
# ./train/images/076052.jpg
# ./train/images/024488.jpg
# ./train/images/092680.jpg
# ./train/images/104099.jpg
# ./train/images/059577.jpg
# ./train/images/007050.jpg
# ./train/images/044409.jpg
# ./train/images/088414.jpg
# ./train/images/082936.jpg
# ./train/images/057507.jpg
# ./train/images/083098.jpg
# ./train/images/072323.jpg
# ./train/images/009126.jpg
# ./train/images/094181.jpg
# ./train/images/092087.jpg
# ./train/images/084830.jpg
# ./train/images/014845.jpg
# ./train/images/091748.jpg
# ./train/images/083634.jpg
# ./train/images/043964.jpg
# ./train/images/016978.jpg
# ./train/images/040342.jpg
# ./train/images/018905.jpg
# ./train/images/052896.jpg
# ./train/images/095431.jpg
# ./train/images/058597.jpg
# ./train/images/023423.jpg
# ./train/images/038548.jpg
# ./train/images/103382.jpg
# ./train/images/046570.jpg
# ./train/images/094781.jpg
# ./train/images/103794.jpg
# ./train/images/087988.jpg
# ./train/images/041742.jpg
# ./train/images/042747.jpg
# ./train/images/070650.jpg
# ./train/images/035586.jpg
# ./train/images/092627.jpg
# ./train/images/031847.jpg
# ./train/images/036840.jpg
# ./train/images/094043.jpg
# ./train/images/039101.jpg
# ./train/images/083506.jpg
# ./train/images/097983.jpg
# ./train/images/077321.jpg
# ./train/images/009269.jpg
# ./train/images/065243.jpg
# ./train/images/015278.jpg
# ./train/images/048138.jpg
# ./train/images/088580.jpg
# ./train/images/056737.jpg
# ./train/images/008881.jpg
# ./train/images/071778.jpg
# ./train/images/029087.jpg
# ./train/images/070564.jpg
# ./train/images/044556.jpg
# ./train/images/052460.jpg
# ./train/images/024578.jpg
# ./train/images/045041.jpg
# ./train/images/097189.jpg
# ./train/images/030933.jpg
# ./train/images/092354.jpg
# ./train/images/039720.jpg
# ./train/images/028580.jpg
# ./train/images/034896.jpg
# ./train/images/029414.jpg
# ./train/images/079981.jpg
# ./train/images/041843.jpg
# ./train/images/022591.jpg
# ./train/images/077152.jpg
# ./train/images/103536.jpg
# ./train/images/033652.jpg
# ./train/images/049166.jpg
# ./train/images/016765.jpg
# ./train/images/041258.jpg
# ./train/images/102432.jpg
# ./train/images/028874.jpg
# ./train/images/069286.jpg
# ./train/images/035736.jpg
# ./train/images/037396.jpg
# ./train/images/036398.jpg
# ./train/images/088868.jpg
# ./train/images/074136.jpg
# ./train/images/044536.jpg
# ./train/images/007494.jpg
# ./train/images/037416.jpg
# ./train/images/007200.jpg
# ./train/images/024068.jpg
# ./train/images/101416.jpg
# ./train/images/080493.jpg
# ./train/images/023971.jpg
# ./train/images/065868.jpg
# ./train/images/008524.jpg
# ./train/images/041328.jpg
# ./train/images/057144.jpg
# ./train/images/067327.jpg
# ./train/images/057209.jpg
# ./train/images/074742.jpg
# ./train/images/092283.jpg
# ./train/images/014998.jpg
# ./train/images/029955.jpg
# ./train/images/077889.jpg
# ./train/images/009715.jpg
# ./train/images/038895.jpg
# ./train/images/055306.jpg
# ./train/images/028403.jpg
# ./train/images/068250.jpg
# ./train/images/011628.jpg
# ./train/images/076482.jpg
# ./train/images/057427.jpg
# ./train/images/018693.jpg
# ./train/images/009752.jpg
# ./train/images/103941.jpg
# ./train/images/017351.jpg
# ./train/images/099029.jpg
# ./train/images/089491.jpg
# ./train/images/042366.jpg
# ./train/images/028013.jpg
# ./train/images/079473.jpg
# ./train/images/083185.jpg
# ./train/images/082315.jpg
# ./train/images/096374.jpg
# ./train/images/078755.jpg
# ./train/images/054588.jpg
# ./train/images/070610.jpg
# ./train/images/045044.jpg
# ./train/images/020381.jpg
# ./train/images/072272.jpg
# ./train/images/092987.jpg
# ./train/images/007850.jpg
# ./train/images/081949.jpg
# ./train/images/095233.jpg
# ./train/images/100386.jpg
# ./train/images/034623.jpg
# ./train/images/032069.jpg
# ./train/images/046261.jpg
# ./train/images/008090.jpg
# ./train/images/035380.jpg
# ./train/images/100628.jpg
# ./train/images/082734.jpg
# ./train/images/085969.jpg
# ./train/images/009582.jpg
# ./train/images/020817.jpg
# ./train/images/099445.jpg
# ./train/images/064825.jpg
# ./train/images/033713.jpg
# ./train/images/041690.jpg
# ./train/images/088730.jpg
# ./train/images/092282.jpg
# ./train/images/037563.jpg
# ./train/images/074946.jpg
# ./train/images/009634.jpg
# ./train/images/050123.jpg
# ./train/images/037180.jpg
# ./train/images/059467.jpg
# ./train/images/016060.jpg
# ./train/images/088533.jpg
# ./train/images/098894.jpg
# ./train/images/083146.jpg
# ./train/images/050317.jpg
# ./train/images/066099.jpg
# ./train/images/076489.jpg
# ./train/images/030089.jpg
# ./train/images/008990.jpg
# ./train/images/024958.jpg
# ./train/images/074912.jpg
# ./train/images/025721.jpg
# ./train/images/069851.jpg
# ./train/images/053765.jpg
# ./train/images/090305.jpg
# ./train/images/067228.jpg
# ./train/images/043301.jpg
# ./train/images/081691.jpg
# ./train/images/037978.jpg
# ./train/images/095295.jpg
# ./train/images/082086.jpg
# ./train/images/024721.jpg
# ./train/images/092383.jpg
# ./train/images/064993.jpg
# ./train/images/021019.jpg
# ./train/images/047068.jpg
# ./train/images/070397.jpg
# ./train/images/074010.jpg
# ./train/images/014049.jpg
# ./train/images/068285.jpg
# ./train/images/039362.jpg
# ./train/images/083144.jpg
# ./train/images/095467.jpg
# ./train/images/012651.jpg
# ./train/images/034890.jpg
# ./train/images/058804.jpg
# ./train/images/020451.jpg
# ./train/images/072247.jpg
# ./train/images/081068.jpg
# ./train/images/025483.jpg
# ./train/images/067104.jpg
# ./train/images/025366.jpg
# ./train/images/087944.jpg
# ./train/images/097680.jpg
# ./train/images/026794.jpg
# ./train/images/069881.jpg
# ./train/images/080984.jpg
# ./train/images/069961.jpg
# ./train/images/029000.jpg
# ./train/images/014287.jpg
# ./train/images/006512.jpg
# ./train/images/079767.jpg
# ./train/images/031276.jpg
# ./train/images/079022.jpg
# ./train/images/102204.jpg
# ./train/images/024401.jpg
# ./train/images/070604.jpg
# ./train/images/077218.jpg
# ./train/images/070307.jpg
# ./train/images/017600.jpg
# ./train/images/052225.jpg
# ./train/images/092032.jpg
# ./train/images/084805.jpg
# ./train/images/101621.jpg
# ./train/images/087265.jpg
# ./train/images/038638.jpg
# ./train/images/089178.jpg
# ./train/images/011179.jpg
# ./train/images/086147.jpg
# ./train/images/056851.jpg
# ./train/images/041546.jpg
# ./train/images/039273.jpg
# ./train/images/027217.jpg
# ./train/images/090074.jpg
# ./train/images/028847.jpg
# ./train/images/087536.jpg
# ./train/images/086164.jpg
# ./train/images/035672.jpg
# ./train/images/101447.jpg
# ./train/images/094932.jpg
# ./train/images/052375.jpg
# ./train/images/100688.jpg
# ./train/images/077544.jpg
# ./train/images/053620.jpg
# ./train/images/006765.jpg
# ./train/images/087544.jpg
# ./train/images/087318.jpg
# ./train/images/080172.jpg
# ./train/images/102077.jpg
# ./train/images/071440.jpg
# ./train/images/096746.jpg
# ./train/images/021053.jpg
# ./train/images/070403.jpg
# ./train/images/044113.jpg
# ./train/images/030105.jpg
# ./train/images/042576.jpg
# ./train/images/051342.jpg
# ./train/images/083264.jpg
# ./train/images/101253.jpg
# ./train/images/016634.jpg
# ./train/images/037644.jpg
# ./train/images/077130.jpg
# ./train/images/036006.jpg
# ./train/images/073764.jpg
# ./train/images/095523.jpg
# ./train/images/029797.jpg
# ./train/images/069995.jpg
# ./train/images/057148.jpg
# ./train/images/087128.jpg
# ./train/images/093470.jpg
# ./train/images/075285.jpg
# ./train/images/082430.jpg
# ./train/images/017127.jpg
# ./train/images/033438.jpg
# ./train/images/032995.jpg
# ./train/images/014653.jpg
# ./train/images/044849.jpg
# ./train/images/094493.jpg
# ./train/images/052766.jpg
# ./train/images/034088.jpg
# ./train/images/028596.jpg
# ./train/images/104370.jpg
# ./train/images/058737.jpg
# ./train/images/071543.jpg
# ./train/images/082911.jpg
# ./train/images/017788.jpg
# ./train/images/094916.jpg
# ./train/images/049476.jpg
# ./train/images/092936.jpg
# ./train/images/079019.jpg
# ./train/images/082851.jpg
# ./train/images/076000.jpg
# ./train/images/046982.jpg
# ./train/images/084518.jpg
# ./train/images/085847.jpg
# ./train/images/082924.jpg
# ./train/images/076910.jpg
# ./train/images/086389.jpg
# ./train/images/031186.jpg
# ./train/images/029042.jpg
# ./train/images/090746.jpg
# ./train/images/056039.jpg
# ./train/images/014415.jpg
# ./train/images/040855.jpg
# ./train/images/095803.jpg
# ./train/images/075991.jpg
# ./train/images/053673.jpg
# ./train/images/042000.jpg
# ./train/images/076617.jpg
# ./train/images/067524.jpg
# ./train/images/031035.jpg
# ./train/images/039463.jpg
# ./train/images/089964.jpg
# ./train/images/041735.jpg
# ./train/images/081783.jpg
# ./train/images/094613.jpg
# ./train/images/096517.jpg
# ./train/images/095494.jpg
# ./train/images/037194.jpg
# ./train/images/060679.jpg
# ./train/images/039193.jpg
# ./train/images/040751.jpg
# ./train/images/053239.jpg
# ./train/images/101769.jpg
# ./train/images/051481.jpg
# ./train/images/078663.jpg
# ./train/images/065910.jpg
# ./train/images/048313.jpg
# ./train/images/024742.jpg
# ./train/images/015663.jpg
# ./train/images/016182.jpg
# ./train/images/044566.jpg
# ./train/images/020668.jpg
# ./train/images/071518.jpg
# ./train/images/007115.jpg
# ./train/images/019854.jpg
# ./train/images/022022.jpg
# ./train/images/067681.jpg
# ./train/images/094895.jpg
# ./train/images/057547.jpg
# ./train/images/061432.jpg
# ./train/images/059714.jpg
# ./train/images/010761.jpg
# ./train/images/071875.jpg
# ./train/images/070554.jpg
# ./train/images/047493.jpg
# ./train/images/039861.jpg
# ./train/images/024255.jpg
# ./train/images/095691.jpg
# ./train/images/028946.jpg
# ./train/images/056451.jpg
# ./train/images/090042.jpg
# ./train/images/101004.jpg
# ./train/images/071349.jpg
# ./train/images/101620.jpg
# ./train/images/076749.jpg
# ./train/images/051214.jpg
# ./train/images/091053.jpg
# ./train/images/099306.jpg
# ./train/images/047989.jpg
# ./train/images/093386.jpg
# ./train/images/051790.jpg
# ./train/images/065125.jpg
# ./train/images/026111.jpg
# ./train/images/038297.jpg
# ./train/images/063045.jpg
# ./train/images/039555.jpg
# ./train/images/036927.jpg
# ./train/images/087453.jpg
# ./train/images/095826.jpg
# ./train/images/015777.jpg
# ./train/images/052922.jpg
# ./train/images/097005.jpg
# ./train/images/103662.jpg
# ./train/images/095028.jpg
# ./train/images/101782.jpg
# ./train/images/010297.jpg
# ./train/images/017769.jpg
# ./train/images/043117.jpg
# ./train/images/054460.jpg
# ./train/images/033857.jpg
# ./train/images/009579.jpg
# ./train/images/034652.jpg
# ./train/images/075663.jpg
# ./train/images/063837.jpg
# ./train/images/060886.jpg
# ./train/images/041162.jpg
# ./train/images/040380.jpg
# ./train/images/021643.jpg
# ./train/images/063617.jpg
# ./train/images/057960.jpg
# ./train/images/081636.jpg
# ./train/images/071270.jpg
# ./train/images/042431.jpg
# ./train/images/045566.jpg
# ./train/images/078049.jpg
# ./train/images/066084.jpg
# ./train/images/040896.jpg
# ./train/images/038590.jpg
# ./train/images/021192.jpg
# ./train/images/046745.jpg
# ./train/images/009457.jpg
# ./train/images/033811.jpg
# ./train/images/012064.jpg
# ./train/images/103265.jpg
# ./train/images/076254.jpg
# ./train/images/095375.jpg
# ./train/images/102777.jpg
# ./train/images/099750.jpg
# ./train/images/079665.jpg
# ./train/images/069779.jpg
# ./train/images/075921.jpg
# ./train/images/049881.jpg
# ./train/images/071476.jpg
# ./train/images/039090.jpg
# ./train/images/070913.jpg
# ./train/images/088457.jpg
# ./train/images/009734.jpg
# ./train/images/082127.jpg
# ./train/images/024309.jpg
# ./train/images/037584.jpg
# ./train/images/090401.jpg
# ./train/images/018844.jpg
# ./train/images/056183.jpg
# ./train/images/071071.jpg
# ./train/images/099781.jpg
# ./train/images/040654.jpg
# ./train/images/044848.jpg
# ./train/images/082211.jpg
# ./train/images/025163.jpg
# ./train/images/049878.jpg
# ./train/images/038709.jpg
# ./train/images/078545.jpg
# ./train/images/098270.jpg
# ./train/images/061474.jpg
# ./train/images/090063.jpg
# ./train/images/035438.jpg
# ./train/images/043674.jpg
# ./train/images/027669.jpg
# ./train/images/043342.jpg
# ./train/images/095031.jpg
# ./train/images/070522.jpg
# ./train/images/082986.jpg
# ./train/images/098938.jpg
# ./train/images/050660.jpg
# ./train/images/058767.jpg
# ./train/images/008721.jpg
# ./train/images/034997.jpg
# ./train/images/026539.jpg
# ./train/images/019540.jpg
# ./train/images/048023.jpg
# ./train/images/009511.jpg
# ./train/images/057686.jpg
# ./train/images/013816.jpg
# ./train/images/036491.jpg
# ./train/images/087855.jpg
# ./train/images/068488.jpg
# ./train/images/009065.jpg
# ./train/images/080802.jpg
# ./train/images/046857.jpg
# ./train/images/020857.jpg
# ./train/images/034722.jpg
# ./train/images/102393.jpg
# ./train/images/101937.jpg
# ./train/images/028406.jpg
# ./train/images/025931.jpg
# ./train/images/051359.jpg
# ./train/images/081855.jpg
# ./train/images/043699.jpg
# ./train/images/080646.jpg
# ./train/images/100140.jpg
# ./train/images/060355.jpg
# ./train/images/038348.jpg
# ./train/images/092079.jpg
# ./train/images/098113.jpg
# ./train/images/033642.jpg
# ./train/images/036135.jpg
# ./train/images/040839.jpg
# ./train/images/101286.jpg
# ./train/images/052917.jpg
# ./train/images/082829.jpg
# ./train/images/097230.jpg
# ./train/images/063448.jpg
# ./train/images/075845.jpg
# ./train/images/100751.jpg
# ./train/images/086179.jpg
# ./train/images/007521.jpg
# ./train/images/037142.jpg
# ./train/images/061330.jpg
# ./train/images/079480.jpg
# ./train/images/089558.jpg
# ./train/images/080800.jpg
# ./train/images/032324.jpg
# ./train/images/036246.jpg
# ./train/images/044110.jpg
# ./train/images/101756.jpg
# ./train/images/062399.jpg
# ./train/images/013106.jpg
# ./train/images/090654.jpg
# ./train/images/022182.jpg
# ./train/images/050443.jpg
# ./train/images/087576.jpg
# ...
# ./train/images/101397.jpg
# ./train/images/022862.jpg
# ./train/images/069947.jpg
# ./train/images/021256.jpg
# ./train/images/037918.jpg
# ./train/images/022995.jpg
# ./train/images/049795.jpg
# ./train/images/053334.jpg
# ./train/images/092417.jpg
# ./train/images/058051.jpg
# ./train/images/103255.jpg
# ./train/images/032887.jpg
# ./train/images/013906.jpg
# ./train/images/045132.jpg
# ./train/images/036227.jpg
# ./train/images/076696.jpg
# ./train/images/026186.jpg
# ./train/images/071573.jpg
# ./train/images/011229.jpg
# ./train/images/034573.jpg
# ./train/images/041712.jpg
# ./train/images/032425.jpg
# ./train/images/063841.jpg
# ./train/images/017108.jpg
# ./train/images/067753.jpg
# ./train/images/074958.jpg
# ./train/images/088358.jpg
# ./train/images/098303.jpg
# ./train/images/080031.jpg
# ./train/images/100753.jpg
# ./train/images/095116.jpg
# ./train/images/011407.jpg
# ./train/images/046364.jpg
# ./train/images/089440.jpg
# ./train/images/079957.jpg
# ./train/images/034693.jpg
# ./train/images/081281.jpg
# ./train/images/036298.jpg
# ./train/images/031514.jpg
# ./train/images/075906.jpg
# ./train/images/077503.jpg
# ./train/images/057297.jpg
# ./train/images/080881.jpg
# ./train/images/033351.jpg
# ./train/images/043937.jpg
# ./train/images/045971.jpg
# ./train/images/075005.jpg
# ./train/images/097470.jpg
# ./train/images/079942.jpg
# ./train/images/091176.jpg
# ./train/images/009677.jpg
# ./train/images/020771.jpg
# ./train/images/043424.jpg
# ./train/images/067805.jpg
# ./train/images/048749.jpg
# ./train/images/009494.jpg
# ./train/images/070361.jpg
# ./train/images/006576.jpg
# ./train/images/010676.jpg
# ./train/images/067380.jpg
# ./train/images/025861.jpg
# ./train/images/093574.jpg
# ./train/images/047991.jpg
# ./train/images/023415.jpg
# ./train/images/043708.jpg
# ./train/images/068881.jpg
# ./train/images/039977.jpg
# ./train/images/054765.jpg
# ./train/images/087583.jpg
# ./train/images/037849.jpg
# ./train/images/041618.jpg
# ./train/images/063174.jpg
# ./train/images/103659.jpg
# ./train/images/037355.jpg
# ./train/images/024750.jpg
# ./train/images/076951.jpg
# ./train/images/069385.jpg
# ./train/images/040312.jpg
# ./train/images/017963.jpg
# ./train/images/082252.jpg
# ./train/images/079249.jpg
# ./train/images/036712.jpg
# ./train/images/008622.jpg
# ./train/images/040080.jpg
# ./train/images/097024.jpg
# ./train/images/059999.jpg
# ./train/images/078266.jpg
# ./train/images/056826.jpg
# ./train/images/101619.jpg
# ./train/images/082926.jpg
# ./train/images/077863.jpg
# ./train/images/075146.jpg
# ./train/images/071169.jpg
# ./train/images/078201.jpg
# ./train/images/081278.jpg
# ./train/images/035953.jpg
# ./train/images/088572.jpg
# ./train/images/009283.jpg
# ./train/images/009162.jpg
# ./train/images/007761.jpg
# ./train/images/030694.jpg
# ./train/images/078154.jpg
# ./train/images/042921.jpg
# ./train/images/092364.jpg
# ./train/images/104187.jpg
# ./train/images/061073.jpg
# ./train/images/085526.jpg
# ./train/images/056485.jpg
# ./train/images/016956.jpg
# ./train/images/048378.jpg
# ./train/images/059943.jpg
# ./train/images/059757.jpg
# ./train/images/067359.jpg
# ./train/images/074748.jpg
# ./train/images/065347.jpg
# ./train/images/056398.jpg
# ./train/images/038103.jpg
# ./train/images/013268.jpg
# ./train/images/095027.jpg
# ./train/images/073502.jpg
# ./train/images/074593.jpg
# ./train/images/025044.jpg
# ./train/images/048763.jpg
# ./train/images/087234.jpg
# ./train/images/037932.jpg
# ./train/images/037066.jpg
# ./train/images/028640.jpg
# ./train/images/063848.jpg
# ./train/images/025945.jpg
# ./train/images/104030.jpg
# ./train/images/100444.jpg
# ./train/images/076308.jpg
# ./train/images/037798.jpg
# ./train/images/082925.jpg
# ./train/images/099088.jpg
# ./train/images/074339.jpg
# ./train/images/077092.jpg
# ./train/images/016144.jpg
# ./train/images/079001.jpg
# ./train/images/103434.jpg
# ./train/images/073203.jpg
# ./train/images/041238.jpg
# ./train/images/016757.jpg
# ./train/images/071607.jpg
# ./train/images/024069.jpg
# ./train/images/046620.jpg
# ./train/images/007217.jpg
# ./train/images/095940.jpg
# ./train/images/094004.jpg
# ./train/images/023874.jpg
# ./train/images/084643.jpg
# ./train/images/036854.jpg
# ./train/images/027453.jpg
# ./train/images/070514.jpg
# ./train/images/035842.jpg
# ./train/images/077549.jpg
# ./train/images/098448.jpg
# ./train/images/036926.jpg
# ./train/images/070196.jpg
# ./train/images/029467.jpg
# ./train/images/054101.jpg
# ./train/images/034664.jpg
# ./train/images/097834.jpg
# ./train/images/084807.jpg
# ./train/images/096458.jpg
# ./train/images/103919.jpg
# ./train/images/050533.jpg
# ./train/images/012099.jpg
# ./train/images/027728.jpg
# ./train/images/081591.jpg
# ./train/images/060326.jpg
# ./train/images/068258.jpg
# ./train/images/076172.jpg
# ./train/images/086469.jpg
# ./train/images/063698.jpg
# ./train/images/084139.jpg
# ./train/images/008222.jpg
# ./train/images/103958.jpg
# ./train/images/084201.jpg
# ./train/images/008778.jpg
# ./train/images/023042.jpg
# ./train/images/099119.jpg
# ./train/images/072097.jpg
# ./train/images/084422.jpg
# ./train/images/041403.jpg
# ./train/images/063644.jpg
# ./train/images/007742.jpg
# ./train/images/038846.jpg
# ./train/images/054080.jpg
# ./train/images/029008.jpg
# ./train/images/097772.jpg
# ./train/images/067863.jpg
# ./train/images/017162.jpg
# ./train/images/020186.jpg
# ./train/images/081078.jpg
# ./train/images/088995.jpg
# ./train/images/070499.jpg
# ./train/images/083845.jpg
# ./train/images/057428.jpg
# ./train/images/071909.jpg
# ./train/images/023507.jpg
# ./train/images/102681.jpg
# ./train/images/075042.jpg
# ./train/images/040595.jpg
# ./train/images/053904.jpg
# ./train/images/070529.jpg
# ./train/images/030770.jpg
# ./train/images/058929.jpg
# ./train/images/073146.jpg
# ./train/images/046996.jpg
# ./train/images/023268.jpg
# ./train/images/029097.jpg
# ./train/images/096358.jpg
# ./train/images/024946.jpg
# ./train/images/059635.jpg
# ./train/images/032670.jpg
# ./train/images/079848.jpg
# ./train/images/066610.jpg
# ./train/images/083154.jpg
# ./train/images/037181.jpg
# ./train/images/008908.jpg
# ./train/images/007509.jpg
# ./train/images/039519.jpg
# ./train/images/065755.jpg
# ./train/images/098407.jpg
# ./train/images/023341.jpg
# ./train/images/079529.jpg
# ./train/images/087110.jpg
# ./train/images/103848.jpg
# ./train/images/070987.jpg
# ./train/images/081526.jpg
# ./train/images/060954.jpg
# ./train/images/076263.jpg
# ./train/images/054173.jpg
# ./train/images/010002.jpg
# ./train/images/009123.jpg
# ./train/images/094741.jpg
# ./train/images/028334.jpg
# ./train/images/086027.jpg
# ./train/images/028009.jpg
# ./train/images/090184.jpg
# ./train/images/012248.jpg
# ./train/images/027274.jpg
# ./train/images/046405.jpg
# ./train/images/058173.jpg
# ./train/images/021931.jpg
# ./train/images/095152.jpg
# ./train/images/012012.jpg
# ./train/images/051543.jpg
# ./train/images/095349.jpg
# ./train/images/095229.jpg
# ./train/images/092315.jpg
# ./train/images/069408.jpg
# ./train/images/024528.jpg
# ./train/images/008001.jpg
# ./train/images/088485.jpg
# ./train/images/042994.jpg
# ./train/images/095154.jpg
# ./train/images/059425.jpg
# ./train/images/074347.jpg
# ./train/images/095011.jpg
# ./train/images/099508.jpg
# ./train/images/056972.jpg
# ./train/images/102277.jpg
# ./train/images/008410.jpg
# ./train/images/035617.jpg
# ./train/images/042240.jpg
# ./train/images/037507.jpg
# ./train/images/069653.jpg
# ./train/images/039575.jpg
# ./train/images/024093.jpg
# ./train/images/019685.jpg
# ./train/images/036434.jpg
# ./train/images/043194.jpg
# ./train/images/068241.jpg
# ./train/images/070641.jpg
# ./train/images/082332.jpg
# ./train/images/030630.jpg
# ./train/images/085022.jpg
# ./train/images/051709.jpg
# ./train/images/040940.jpg
# ./train/images/030164.jpg
# ./train/images/081021.jpg
# ./train/images/093994.jpg
# ./train/images/096918.jpg
# ./train/images/082216.jpg
# ./train/images/015573.jpg
# ./train/images/052893.jpg
# ./train/images/013533.jpg
# ./train/images/052172.jpg
# ./train/images/064753.jpg
# ./train/images/047664.jpg
# ./train/images/094910.jpg
# ./train/images/075909.jpg
# ./train/images/036546.jpg
# ./train/images/077436.jpg
# ./train/images/038688.jpg
# ./train/images/034824.jpg
# ./train/images/098741.jpg
# ./train/images/084102.jpg
# ./train/images/034571.jpg
# ./train/images/085111.jpg
# ./train/images/087478.jpg
# ./train/images/082275.jpg
# ./train/images/078260.jpg
# ./train/images/066526.jpg
# ./train/images/094759.jpg
# ./train/images/075276.jpg
# ./train/images/032196.jpg
# ./train/images/073777.jpg
# ./train/images/102421.jpg
# ./train/images/006639.jpg
# ./train/images/072524.jpg
# ./train/images/008880.jpg
# ./train/images/085356.jpg
# ./train/images/082432.jpg
# ./train/images/014384.jpg
# ./train/images/068382.jpg
# ./train/images/066520.jpg
# ./train/images/064286.jpg
# ./train/images/075597.jpg
# ./train/images/041801.jpg
# ./train/images/071879.jpg
# ./train/images/082820.jpg
# ./train/images/080135.jpg
# ./train/images/006953.jpg
# ./train/images/088441.jpg
# ./train/images/103187.jpg
# ./train/images/103431.jpg
# ./train/images/091984.jpg
# ./train/images/045916.jpg
# ./train/images/032759.jpg
# ./train/images/007974.jpg
# ./train/images/094199.jpg
# ./train/images/072352.jpg
# ./train/images/095755.jpg
# ./train/images/009001.jpg
# ./train/images/070438.jpg
# ./train/images/027400.jpg
# ./train/images/093397.jpg
# ./train/images/072610.jpg
# ./train/images/053320.jpg
# ./train/images/078419.jpg
# ./train/images/071080.jpg
# ./train/images/051228.jpg
# ./train/images/047612.jpg
# ./train/images/080583.jpg
# ./train/images/027053.jpg
# ./train/images/039984.jpg
# ./train/images/073567.jpg
# ./train/images/040851.jpg
# ./train/images/094014.jpg
# ./train/images/095410.jpg
# ./train/images/100853.jpg
# ./train/images/045704.jpg
# ./train/images/017605.jpg
# ./train/images/072706.jpg
# ./train/images/032411.jpg
# ./train/images/085103.jpg
# ./train/images/097721.jpg
# ./train/images/091102.jpg
# ./train/images/026899.jpg
# ./train/images/028901.jpg
# ./train/images/007089.jpg
# ./train/images/050322.jpg
# ./train/images/026412.jpg
# ./train/images/102494.jpg
# ./train/images/078577.jpg
# ./train/images/094260.jpg
# ./train/images/037867.jpg
# ./train/images/099507.jpg
# ./train/images/060996.jpg
# ./train/images/068844.jpg
# ./train/images/059881.jpg
# ./train/images/046081.jpg
# ./train/images/009963.jpg
# ./train/images/099779.jpg
# ./train/images/021955.jpg
# ./train/images/009690.jpg
# ./train/images/096693.jpg
# ./train/images/051555.jpg
# ./train/images/082765.jpg
# ./train/images/032263.jpg
# ./train/images/017953.jpg
# ./train/images/100329.jpg
# ./train/images/033867.jpg
# ./train/images/086489.jpg
# ./train/images/091214.jpg
# ./train/images/083110.jpg
# ./train/images/082958.jpg
# ./train/images/041218.jpg
# ./train/images/017965.jpg
# ./train/images/007374.jpg
# ./train/images/041437.jpg
# ./train/images/103297.jpg
# ./train/images/092859.jpg
# ./train/images/098800.jpg
# ./train/images/084447.jpg
# ./train/images/038277.jpg
# ./train/images/039123.jpg
# ./train/images/011834.jpg
# ./train/images/091145.jpg
# ./train/images/026132.jpg
# ./train/images/057330.jpg
# ./train/images/053385.jpg
# ./train/images/049063.jpg
# ./train/images/056811.jpg
# ./train/images/067679.jpg
# ./train/images/093350.jpg
# ./train/images/013659.jpg
# ./train/images/099077.jpg
# ./train/images/080343.jpg
# ./train/images/007574.jpg
# ./train/images/101265.jpg
# ./train/images/039721.jpg
# ./train/images/014199.jpg
# ./train/images/031814.jpg
# ./train/images/102117.jpg
# ./train/images/096772.jpg
# ./train/images/073032.jpg
# ./train/images/065398.jpg
# ./train/images/023265.jpg
# ./train/images/013851.jpg
# ./train/images/095631.jpg
# ./train/images/073418.jpg
# ./train/images/046298.jpg
# ./train/images/037506.jpg
# ./train/images/035313.jpg
# ./train/images/042468.jpg
# ./train/images/104323.jpg
# ./train/images/086803.jpg
# ./train/images/069576.jpg
# ./train/images/048660.jpg
# ./train/images/013517.jpg
# ./train/images/033019.jpg
# ./train/images/011243.jpg
# ./train/images/031596.jpg
# ./train/images/072838.jpg
# ./train/images/101103.jpg
# ./train/images/049222.jpg
# ./train/images/042007.jpg
# ./train/images/077140.jpg
# ./train/images/038528.jpg
# ./train/images/094793.jpg
# ./train/images/100822.jpg
# ./train/images/084053.jpg
# ./train/images/065192.jpg
# ./train/images/023928.jpg
# ./train/images/044833.jpg
# ./train/images/087676.jpg
# ./train/images/091880.jpg
# ./train/images/034656.jpg
# ./train/images/025414.jpg
# ./train/images/015492.jpg
# ./train/images/085243.jpg
# ./train/images/022943.jpg
# ./train/images/012066.jpg
# ./train/images/028655.jpg
# ./train/images/009322.jpg
# ./train/images/069057.jpg
# ./train/images/037015.jpg
# ./train/images/090668.jpg
# ./train/images/097139.jpg
# ./train/images/072298.jpg
# ./train/images/103420.jpg
# ./train/images/099317.jpg
# ./train/images/026669.jpg
# ./train/images/063676.jpg
# ./train/images/096543.jpg
# ./train/images/008197.jpg
# ./train/images/076615.jpg
# ./train/images/046913.jpg
# ./train/images/054423.jpg
# ./train/images/088376.jpg
# ./train/images/104290.jpg
# ./train/images/095252.jpg
# ./train/images/036839.jpg
# ./train/images/072375.jpg
# ./train/images/065828.jpg
# ./train/images/066727.jpg
# ./train/images/094175.jpg
# ./train/images/052343.jpg
# ./train/images/020136.jpg
# ./train/images/099941.jpg
# ./train/images/008851.jpg
# ./train/images/055120.jpg
# ./train/images/101845.jpg
# ./train/images/103462.jpg
# ./train/images/037794.jpg
# ./train/images/012327.jpg
# ./train/images/078272.jpg
# ./train/images/093162.jpg
# ./train/images/053592.jpg
# ./train/images/013044.jpg
# ./train/images/075015.jpg
# ./train/images/090745.jpg
# ./train/images/069583.jpg
# ./train/images/094399.jpg
# ./train/images/075077.jpg
# ./train/images/023683.jpg
# ./train/images/029738.jpg
# ./train/images/088521.jpg
# ./train/images/080087.jpg
# ./train/images/031305.jpg
# ./train/images/082945.jpg
# ./train/images/060715.jpg
# ./train/images/011304.jpg
# ./train/images/062297.jpg
# ./train/images/103703.jpg
# ./train/images/084287.jpg
# ./train/images/022914.jpg
# ./train/images/019836.jpg
# ./train/images/048374.jpg
# ./train/images/084260.jpg
# ./train/images/090075.jpg
# ./train/images/048588.jpg
# ./train/images/068434.jpg
# ./train/images/081902.jpg
# ./train/images/017973.jpg
# ./train/images/026657.jpg
# ./train/images/068716.jpg
# ./train/images/038656.jpg
# ./train/images/062611.jpg
# ./train/images/087205.jpg
# ./train/images/030870.jpg
# ./train/images/052098.jpg
# ./train/images/054482.jpg
# ./train/images/040092.jpg
# ./train/images/066988.jpg
# ./train/images/054371.jpg
# ./train/images/030785.jpg
# ./train/images/017752.jpg
# ./train/images/086997.jpg
# ./train/images/104113.jpg
# ./train/images/049999.jpg
# ./train/images/028131.jpg
# ./train/images/086888.jpg
# ./train/images/075715.jpg
# ./train/images/059950.jpg
# ./train/images/029003.jpg
# ./train/images/019490.jpg
# ./train/images/049530.jpg
# ./train/images/079742.jpg
# ./train/images/058441.jpg
# ./train/images/092467.jpg
# ./train/images/094883.jpg
# ./train/images/026077.jpg
# ./train/images/071718.jpg
# ./train/images/095022.jpg
# ./train/images/083020.jpg
# ./train/images/041994.jpg
# ./train/images/010492.jpg
# ./train/images/052712.jpg
# ./train/images/075008.jpg
# ./train/images/011806.jpg
# ./train/images/008479.jpg
# ./train/images/065896.jpg
# ./train/images/063046.jpg
# ./train/images/016700.jpg
# ./train/images/051816.jpg
# ./train/images/024310.jpg
# ./train/images/042463.jpg
# ./train/images/024960.jpg
# ./train/images/078852.jpg
# ./train/images/020816.jpg
# ./train/images/083247.jpg
# ./train/images/098010.jpg
# ./train/images/069742.jpg
# ./train/images/033322.jpg
# ./train/images/011102.jpg
# ./train/images/034976.jpg
# ./train/images/061549.jpg
# ./train/images/032496.jpg
# ./train/images/101822.jpg
# ./train/images/017627.jpg
# ./train/images/052163.jpg
# ./train/images/013095.jpg
# ./train/images/081984.jpg
# ./train/images/070074.jpg
# ./train/images/086296.jpg
# ./train/images/037512.jpg
# ./train/images/014106.jpg
# ./train/images/084792.jpg
# ./train/images/080629.jpg
# ./train/images/051560.jpg
# ./train/images/028746.jpg
# ./train/images/016974.jpg
# ./train/images/038735.jpg
# ./train/images/099028.jpg
# ./train/images/076589.jpg
# ./train/images/051216.jpg
# ./train/images/090341.jpg
# ./train/images/081599.jpg
# ./train/images/009443.jpg
# ./train/images/014741.jpg
# ./train/images/055016.jpg
# ./train/images/023259.jpg
# ./train/images/052081.jpg
# ./train/images/069688.jpg
# ./train/images/083626.jpg
# ./train/images/089470.jpg
# ./train/images/044231.jpg
# ./train/images/085538.jpg
# ./train/images/095537.jpg
# ./train/images/069748.jpg
# ./train/images/008247.jpg
# ./train/images/013849.jpg
# ./train/images/080891.jpg
# ./train/images/069895.jpg
# ./train/images/089672.jpg
# ./train/images/069276.jpg
# ./train/images/079209.jpg
# ./train/images/007721.jpg
# ./train/images/008029.jpg
# ./train/annotations.json

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
def precision(mask, y_pred, threshold=0.6):
  y = y_pred > threshold
  real_cats = tf.math.reduce_any(tf.cast(mask, dtype=tf.bool), axis=[1, 2])
  cats = tf.math.reduce_any(y, axis=[1, 2])
  true_positive = tf.math.count_nonzero(tf.boolean_mask(real_cats, cats))
  tp_plus_fp = tf.math.count_nonzero(cats)
  if tp_plus_fp == 0:
    return tf.cast(0, dtype=tf.float64);
  return true_positive / tp_plus_fp

# %%
def IoU(mask, y_pred, threshold=0.6):
  y = y_pred > threshold
  intersection = tf.math.count_nonzero(tf.boolean_mask(y, mask))
  union = tf.math.count_nonzero(mask + tf.cast(y, dtype=tf.float32))
  return  intersection / union

# %%
def precisionWithIoU(mask, y_pred, threshold_max=0.77, threshold=0.4):
  y_max = y_pred > threshold_max
  y = y_pred > threshold 
  real_cats = tf.math.reduce_any(tf.cast(mask, dtype=tf.bool), axis=[1, 2])
  cats = tf.math.reduce_any(y_max, axis=[1, 2])
  number_of_prediction = tf.math.count_nonzero(cats)
  if number_of_prediction == 0:
    return tf.cast(0, dtype=tf.float64)

  intersections = tf.math.count_nonzero(tf.logical_and(tf.cast(mask, dtype=tf.bool), y), axis=[1, 2])
  unions = tf.math.count_nonzero(tf.logical_or(tf.cast(mask, dtype=tf.bool), y), axis=[1, 2])
  ious = intersections / unions
  predicted_cats = tf.logical_and(ious > 0.5, cats)
  true_positive = tf.math.count_nonzero(tf.logical_and(real_cats, predicted_cats))

  return true_positive / number_of_prediction

# %%
def true_positive(mask, y_pred, threshold_max=0.77, threshold=0.4):
  y_max = y_pred > threshold_max
  y = y_pred > threshold 
  real_cats = tf.math.reduce_any(tf.cast(mask, dtype=tf.bool), axis=[1, 2])
  cats = tf.math.reduce_any(y_max, axis=[1, 2])

  intersections = tf.math.count_nonzero(tf.logical_and(tf.cast(mask, dtype=tf.bool), y), axis=[1, 2])
  unions = tf.math.count_nonzero(tf.logical_or(tf.cast(mask, dtype=tf.bool), y), axis=[1, 2])
  ious = intersections / unions
  predicted_cats = tf.logical_and(ious > 0.5, cats)

  return tf.math.count_nonzero(tf.logical_and(real_cats, predicted_cats))

def true_negative(mask, y_pred, threshold_max=0.77, threshold=0.4):
  y_max = y_pred > threshold_max
  real_cats = tf.math.reduce_any(tf.cast(mask, dtype=tf.bool), axis=[1, 2])
  cats = tf.math.reduce_any(y_max, axis=[1, 2])
  true_negative_chan = tf.logical_not(tf.logical_or(cats, real_cats))
  return tf.math.count_nonzero(true_negative_chan)

def false_positive(mask, y_pred, threshold_max=0.77, threshold=0.4):
  y_max = y_pred > threshold_max
  cats = tf.math.reduce_any(y_max, axis=[1, 2])
  return tf.math.count_nonzero(cats) - true_positive(mask, y_pred, threshold_max, threshold)

def false_negative(mask, y_pred, threshold_max=0.77, threshold=0.4):
  y_max = y_pred > threshold_max
  cats = tf.math.reduce_any(y_max, axis=[1, 2])
  return tf.math.count_nonzero(tf.logical_not(cats)) - true_negative(mask, y_pred, threshold_max, threshold)

# %%
segnet = tf.keras.models.load_model('/content/gdrive/MyDrive/challenge/models/segnet/model140', custom_objects={"SegNet": SegNet}, compile=False)

unet = tf.keras.models.load_model('/content/gdrive/MyDrive/challenge/models/unet/architecture', custom_objects={"UNet": UNet}, compile=False)
unet.load_weights('/content/gdrive/MyDrive/challenge/models/unet/weights/unet_weights_epoch100.h5')

# %%
model = EnsembleNet([segnet, unet])

# %%
file = open("train/annotations.json", "r")
annotations = json.loads(file.read())

ann = pd.DataFrame(annotations['annotations'])
mapping = {item:i for i, item in enumerate(ann["category_id"].unique())}
categories = pd.DataFrame(annotations['categories'])
categories['id'] = categories['id'].apply(lambda x: mapping[x])
categories = categories.set_index('id')

file_ = open("val/annotations.json", "r")
annotations = json.loads(file_.read())

ann = pd.DataFrame(annotations['annotations'])
ann["category_id"] = ann["category_id"].apply(lambda x: mapping[x])
annotations_map = {img_id: {} for img_id in ann['image_id'].unique()}
for index, row in ann.iterrows():
    annotations_map[row['image_id']][row['category_id']] = row['segmentation']
images = pd.DataFrame(annotations['images'])
images = images.set_index('id')

np.random.seed(0)
msk = np.random.rand(len(images)) < 0.5
val_images = images[msk]
test_images = images[~msk]

val_set = FoodSequence(val_images, annotations_map, len(categories), batch_size=1, folder='val',img_size=(256, 256), data_augmentation=False)
test_set = FoodSequence(test_images, annotations_map, len(categories), batch_size=1, folder='val',img_size=(256, 256), data_augmentation=False)

# %%
model.compile(metrics=[true_positive, false_positive, true_negative, false_negative])
model.evaluate(test_set)
# Out:
# 620/620 [==============================] - 2402s 4s/step - loss: 0.0000e+00 - true_positive: 0.2935 - false_positive: 1.4952 - true_negative: 269.9290 - false_negative: 1.2823
# [0.0,
#  0.2935483753681183,
#  1.4951612949371338,
#  269.9290466308594,
#  1.2822580337524414]

# %%
from functools import partial

ths = [0.4, 0.5, 0.6, 0.7, 0.8, 0.9]
ious = []

for threshold in ths:
  model.compile(metrics=partial(precision, threshold=threshold))
  results = model.evaluate(val_set)
  ious.append(results[1])

# %%
plt.plot(ths, ious);
plt.title("Precision with different thresholds");

# %%
def desired_output(img_shape, segmentations):
        desired_output = np.zeros((img_shape[0], img_shape[1], len(categories)), dtype=np.int32)

        for i in segmentations:
          t = np.zeros((img_shape[0], img_shape[1], 1), dtype=np.int32)
          for seg in segmentations[i]:
              s = np.array(seg, dtype=np.int32).reshape((-1, 2))
              t = cv2.fillPoly(t, [s], 255)

          desired_output[:, :, i] = t.squeeze()

        return desired_output / 255

# %%
threshold = 0.58
img_id = val_images.sample().index.values[0]
print("Sample n°", img_id)
img = cv2.imread('val/images/' + val_images.loc[img_id, 'file_name'])

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB));

input_img = cv2.resize(img, dsize=(256, 256)) / 255
y = model.predict(input_img.reshape((1, input_img.shape[0], input_img.shape[1], input_img.shape[2])))

img_ann = ann[ann['image_id'] == img_id]
segmentations = dict(zip(img_ann['category_id'], img_ann['segmentation']))
y_true = desired_output(img.shape, segmentations)
y_true = cv2.resize(y_true, dsize=(256, 256), interpolation=cv2.INTER_NEAREST)

print("IoU: ", IoU(y_true, y[0], threshold=threshold))

y = y > threshold
for i in range(len(categories)):
  if np.any(y[0, :, :, i]):
    fig = plt.figure()
    plt.title(categories.iloc[i]['name'] + " - max " + str(np.max(y[0, :, :, i])))
    plt.imshow(y[0, :, :, i], cmap='gray', vmin=0, vmax=1)
